# %%
import mastery_updater

# %%
unique_uids = [7, 8]
tids = ["task1", "task2", "task3", "task4"]

# %%
uids = []
for i, uid in enumerate(unique_uids):
    uids.append(i)
user_masteries = mastery_updater.FullMasteries(uids, tids)
correct_init, (source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size) = mastery_updater.initialise_cv()
# Out:
# {(0, 0): array([59, 28], dtype=int64), (0, 1): array([85, 28], dtype=int64), (0, 2): array([111,  28], dtype=int64), (0, 3): array([137,  28], dtype=int64), (0, 4): array([162,  28], dtype=int64), (0, 5): array([188,  28], dtype=int64), (0, 6): array([214,  28], dtype=int64), (1, 0): array([59, 54], dtype=int64), (1, 1): array([85, 54], dtype=int64), (1, 2): array([111,  54], dtype=int64), (1, 3): array([137,  54], dtype=int64), (1, 4): array([162,  54], dtype=int64), (1, 5): array([188,  54], dtype=int64), (1, 6): array([214,  54], dtype=int64), (2, 0): array([59, 80], dtype=int64), (2, 1): array([85, 80], dtype=int64), (2, 2): array([111,  80], dtype=int64), (2, 3): array([137,  80], dtype=int64), (2, 4): array([162,  80], dtype=int64), (2, 5): array([188,  80], dtype=int64), (2, 6): array([214,  80], dtype=int64), (3, 0): array([ 59, 106], dtype=int64), (3, 1): array([ 85, 106], dtype=int64), (3, 2): array([111, 106], dtype=int64), (3, 3): array([137, 106], dtype=int64), (3, 4): array([162, 106], dtype=int64), (3, 5): array([188, 106], dtype=int64), (3, 6): array([214, 106], dtype=int64), (4, 0): array([ 59, 131], dtype=int64), (4, 1): array([ 85, 131], dtype=int64), (4, 2): array([111, 131], dtype=int64), (4, 3): array([137, 131], dtype=int64), (4, 4): array([162, 131], dtype=int64), (4, 5): array([188, 131], dtype=int64), (4, 6): array([214, 131], dtype=int64), (5, 0): array([ 59, 157], dtype=int64), (5, 1): array([ 85, 157], dtype=int64), (5, 2): array([111, 157], dtype=int64), (5, 3): array([137, 157], dtype=int64), (5, 4): array([162, 157], dtype=int64), (5, 5): array([188, 157], dtype=int64), (5, 6): array([214, 157], dtype=int64), (6, 0): array([ 59, 183], dtype=int64), (6, 1): array([ 85, 183], dtype=int64), (6, 2): array([111, 183], dtype=int64), (6, 3): array([137, 183], dtype=int64), (6, 4): array([162, 183], dtype=int64), (6, 5): array([188, 183], dtype=int64), (6, 6): array([214, 183], dtype=int64), (7, 0): array([ 59, 209], dtype=int64), (7, 1): array([ 85, 209], dtype=int64), (7, 2): array([111, 209], dtype=int64), (7, 3): array([137, 209], dtype=int64), (7, 4): array([162, 209], dtype=int64), (7, 5): array([188, 209], dtype=int64), (7, 6): array([214, 209], dtype=int64)}

# %%
if correct_init:
    print(unique_uids)
    valid_task, beliefs = mastery_updater.run_task(user_masteries, uids, unique_uids, source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size)
    if valid_task:
        user_masteries.move_to_next_task(beliefs)
# Out:
# [7, 8]
# Hand On Board!
# 0.39467382431030273
# Hand On Board!
# 0.6997723579406738
# Hand On Board!
# 0.7568297386169434
# Hand On Board!
# 0.759735107421875
# 5
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0} {} {} {} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {} {} {}
# {'b1': 0.0} {'b1': 1.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7275125980377197
# Hand On Board!
# 0.7299196720123291
# Hand On Board!
# 0.750171422958374
# Hand On Board!
# 0.7560920715332031
# 12
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0} {} {} {'la1': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la1': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0} {} {} {'la1': 2.0} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8129973411560059
# Hand On Board!
# 0.8103837966918945
# Hand On Board!
# 0.8033974170684814
# Hand On Board!
# 0.7429304122924805
# Hand On Board!
# 0.7867271900177002
# Hand On Board!
# 0.6754260063171387
# Hand On Board!
# 0.855100154876709
# 22
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0, 'w1': 2.0} {'w1': 2.0} {'w1': 2.0} {'la1': 2.0, 'w1': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la1': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0} {} {} {'la1': 2.0} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7535228729248047
# Hand On Board!
# 0.7352039813995361
# 26
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0, 'w1': 2.0} {'w1': 2.0} {'w1': 2.0} {'la1': 2.0, 'w1': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la1': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0} {'bsw1': 2.0, 'sw1': 2.0} {'bsw1': 0.0, 'sw1': 0.0} {'la1': 2.0, 'bsw1': 2.0, 'sw1': 2.0} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7361187934875488
# Hand On Board!
# 0.7466964721679688
# Hand On Board!
# 0.7472052574157715
# Hand On Board!
# 0.8358385562896729
# Hand On Board!
# 0.6090748310089111
# Hand On Board!
# 0.6117784976959229
# 33
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0, 'w1': 2.0} {'w1': 2.0} {'w1': 2.0} {'w1': 2.0, 'mo1': -1.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'mo1': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0, 'w4': 2.0} {'sw1': 2.0, 'w4': 2.0} {'sw1': 0.0} {'sw1': 2.0, 'mo1': 1.0} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8304915428161621
# 35
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0, 'w1': 2.0} {'w1': 2.0} {'w1': 2.0} {'w1': 2.0, 'la7': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la7': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0, 'w4': 2.0} {'sw1': 2.0, 'w4': 2.0} {'sw1': 0.0} {'sw1': 2.0, 'la7': 2.0} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7641849517822266
# Hand On Board!
# 0.7443130016326904
# 40
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0, 'w1': 2.0} {'w1': 2.0} {'w1': 2.0} {'w1': 2.0, 'la7': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la7': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0} {'sw1': 2.0, 'bsw2': 2.0} {'sw1': 0.0, 'bsw2': 0.0} {'sw1': 2.0, 'la7': 2.0, 'bsw2': 2.0} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.808405876159668
# 42
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0, 'w1': 2.0} {'w1': 2.0} {'w1': 2.0} {'w1': 2.0, 'la7': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la7': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0} {'sw1': 2.0, 'bsw2': 2.0} {'sw1': 0.0, 'bsw2': 0.0} {'sw1': 2.0, 'la7': 2.0, 'bsw2': 2.0} {} {}
# {} {'w13': 2.0} {'w13': 2.0} {} {} {} {}
#
# Hand On Board!
# 0.740131139755249
# Hand On Board!
# 0.6105630397796631
# Hand On Board!
# 0.6402432918548584
# Hand On Board!
# 0.7475330829620361
# Hand On Board!
# 0.6124746799468994
# Hand On Board!
# 0.6461246013641357
# Hand On Board!
# 0.7100377082824707
# Hand On Board!
# 0.7201478481292725
# Hand On Board!
# 0.6734035015106201
# Hand On Board!
# 0.7982544898986816
# Hand On Board!
# 0.6552767753601074
# Hand On Board!
# 0.7028372287750244
# Hand On Board!
# 0.6312241554260254
# Hand On Board!
# 0.734079122543335
# Hand On Board!
# 0.6877882480621338
# Hand On Board!
# 0.7006781101226807
# Hand On Board!
# 0.6181700229644775
# Hand On Board!
# 0.7862656116485596
# Hand On Board!
# 0.6934034824371338
# Hand On Board!
# 0.6308944225311279
# Hand On Board!
# 0.6236112117767334
# Hand On Board!
# 0.7102484703063965
# Hand On Board!
# 0.6281166076660156
# Hand On Board!
# 0.8695330619812012
# Hand On Board!
# 0.690222978591919
# Hand On Board!
# 0.6856906414031982
# Hand On Board!
# 0.8177330493927002
# Hand On Board!
# 0.8098628520965576
# 71
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0} {} {'w16': 2.0} {'la7': 2.0, 'w16': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la7': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0, 'w15': 2.0} {'sw1': 2.0, 'w17': 2.0} {'sw1': 0.0} {'sw1': 2.0, 'la7': 2.0} {} {}
# {} {'w13': 2.0, 'w15': 2.0} {'w13': 2.0, 'w17': 2.0} {} {} {} {}
#
# Hand On Board!
# 0.8222005367279053
# 73
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0, 'w21': 2.0} {'w21': 2.0} {'w21': 2.0} {'la7': 2.0, 'w21': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la7': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0, 'w15': 2.0} {'sw1': 2.0, 'w17': 2.0, 'bsw4': 2.0} {'sw1': 0.0, 'bsw4': 0.0} {'sw1': 2.0, 'la7': 2.0, 'bsw4': 2.0} {} {}
# {} {'w13': 2.0, 'w15': 2.0} {'w13': 2.0, 'w17': 2.0} {} {} {} {}
#
# OUTPUTS:
# 0: b1 battery piece added 0.0 5,
# la1 lamp piece added 0.0 12,
# w1 wire piece added 1.0 22,
# connection added 1.0 22,
# bsw1 button_switch piece added 0.0 26,
# connection added 0.0 26,
# sw1 switch piece added 0.0 26,
# connection added 0.0 26,
# mo1 motor piece added 0.16666666666666666 33,
# connection added 0.16666666666666666 33,
# w4 wire piece added 0.16666666666666666 33,
# connection added 0.16666666666666666 33,
# closed added 0.16666666666666666 33,
# parallel added 0.16666666666666666 33,
# la1 lamp piece removed 0.16666666666666666 33,
# connection removed 0.16666666666666666 33,
# bsw1 button_switch piece removed 0.16666666666666666 33,
# connection removed 0.16666666666666666 33,
# la7 lamp piece added 1.0 35,
# connection added 1.0 35,
# closed added 1.0 35,
# parallel added 1.0 35,
# mo1 motor piece removed 1.0 35,
# connection removed 1.0 35,
# bsw2 button_switch piece added 1.0 40,
# connection added 1.0 40,
# closed added 1.0 40,
# parallel added 1.0 40,
# w4 wire piece removed 1.0 40,
# connection removed 1.0 40,
# w13 wire piece added 1.0 42,
# w15 wire piece added 0.9333333333333333 71,
# connection added 0.9333333333333333 71,
# w16 wire piece added 0.9333333333333333 71,
# connection added 0.9333333333333333 71,
# w17 wire piece added 0.9333333333333333 71,
# connection added 0.9333333333333333 71,
# closed added 0.9333333333333333 71,
# parallel added 0.9333333333333333 71,
# w1 wire piece removed 0.9333333333333333 71,
# connection removed 0.9333333333333333 71,
# bsw2 button_switch piece removed 0.9333333333333333 71,
# connection removed 0.9333333333333333 71,
# bsw4 button_switch piece added 1.0 73,
# connection added 1.0 73,
# w21 wire piece added 1.0 73,
# connection added 1.0 73,
# closed added 1.0 73,
# parallel added 1.0 73,
# w16 wire piece removed 1.0 73,
# connection removed 1.0 73,
#
# 1: b1 battery piece added 1.0 5,
# la1 lamp piece added 1.0 12,
# w1 wire piece added 0.0 22,
# connection added 0.0 22,
# bsw1 button_switch piece added 1.0 26,
# connection added 1.0 26,
# sw1 switch piece added 1.0 26,
# connection added 1.0 26,
# mo1 motor piece added 0.8333333333333334 33,
# connection added 0.8333333333333334 33,
# w4 wire piece added 0.8333333333333334 33,
# connection added 0.8333333333333334 33,
# closed added 0.8333333333333334 33,
# parallel added 0.8333333333333334 33,
# la1 lamp piece removed 0.8333333333333334 33,
# connection removed 0.8333333333333334 33,
# bsw1 button_switch piece removed 0.8333333333333334 33,
# connection removed 0.8333333333333334 33,
# la7 lamp piece added 0.0 35,
# connection added 0.0 35,
# closed added 0.0 35,
# parallel added 0.0 35,
# mo1 motor piece removed 0.0 35,
# connection removed 0.0 35,
# bsw2 button_switch piece added 0.0 40,
# connection added 0.0 40,
# closed added 0.0 40,
# parallel added 0.0 40,
# w4 wire piece removed 0.0 40,
# connection removed 0.0 40,
# w13 wire piece added 0.0 42,
# w15 wire piece added 0.06666666666666667 71,
# connection added 0.06666666666666667 71,
# w16 wire piece added 0.06666666666666667 71,
# connection added 0.06666666666666667 71,
# w17 wire piece added 0.06666666666666667 71,
# connection added 0.06666666666666667 71,
# closed added 0.06666666666666667 71,
# parallel added 0.06666666666666667 71,
# w1 wire piece removed 0.06666666666666667 71,
# connection removed 0.06666666666666667 71,
# bsw2 button_switch piece removed 0.06666666666666667 71,
# connection removed 0.06666666666666667 71,
# bsw4 button_switch piece added 0.0 73,
# connection added 0.0 73,
# w21 wire piece added 0.0 73,
# connection added 0.0 73,
# closed added 0.0 73,
# parallel added 0.0 73,
# w16 wire piece removed 0.0 73,
# connection removed 0.0 73,
#
#
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b1': 0.0} {'b1': -1.0, 'w21': 2.0} {'w21': 2.0} {'w21': 2.0} {'la7': 2.0, 'w21': 2.0} {} {}
# {'b1': 0.0} {'b1': 0.0} {} {} {'la7': 0.0} {} {}
# {'b1': 0.0} {'b1': 1.0, 'w15': 2.0} {'sw1': 2.0, 'w17': 2.0, 'bsw4': 2.0} {'sw1': 0.0, 'bsw4': 0.0} {'sw1': 2.0, 'la7': 2.0, 'bsw4': 2.0} {} {}
# {} {'w13': 2.0, 'w15': 2.0} {'w13': 2.0, 'w17': 2.0} {} {} {} {}

# %%
if correct_init:
    print(unique_uids)
    valid_task, beliefs = mastery_updater.run_task(user_masteries, uids, unique_uids, source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size)
    if valid_task:
        user_masteries.move_to_next_task(beliefs)
# Out:
# [7, 8]
# Hand On Board!
# 0.7793583869934082
# Hand On Board!
# 0.7203431129455566
# Hand On Board!
# 0.7293298244476318
# Hand On Board!
# 0.8132607936859131
# Hand On Board!
# 0.7096917629241943
# Hand On Board!
# 0.6969523429870605
# Hand On Board!
# 0.7176361083984375
# 15
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0} {} {} {} {} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {} {}
# {'b64': 0.0} {'b64': 1.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# 17
# {} {'led1': 1.0} {'led1': 0.0} {'led1': -1.0} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0} {} {} {} {} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {} {}
# {'b64': 0.0} {'b64': 1.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8090171813964844
# Hand On Board!
# 0.8015317916870117
# 21
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0} {'led2': -1.0} {'led2': 0.0} {'led2': 1.0} {} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {} {}
# {'b64': 0.0} {'b64': 1.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.71366286277771
# 23
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0} {} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {} {}
# {'b64': 0.0} {'b64': 1.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.804091215133667
# Hand On Board!
# 0.8033590316772461
# Hand On Board!
# 0.8052215576171875
# Hand On Board!
# 0.7601556777954102
# Hand On Board!
# 0.731621265411377
# Hand On Board!
# 0.8017144203186035
# 32
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0, 'w213': 2.0} {'mo2': -1.0, 'w213': 2.0} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {'mo2': 0.0} {}
# {'b64': 0.0} {'b64': 1.0} {} {} {} {'mo2': 1.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7496950626373291
# Hand On Board!
# 0.747462272644043
# 38
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0, 'w213': 2.0} {'mo2': -1.0, 'w213': 2.0} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {'mo2': 0.0} {}
# {'b64': 0.0} {'b64': 1.0} {'bsw24': 2.0} {'bsw24': 0.0} {'bsw24': 2.0} {'mo2': 1.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8168325424194336
# 40
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0, 'w213': 2.0} {'mo2': -1.0, 'w213': 2.0} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {'mo2': 0.0} {}
# {'b64': 0.0} {'b64': 1.0, 'w223': 2.0} {'bsw24': 2.0, 'w223': 2.0} {'bsw24': 0.0} {'bsw24': 2.0} {'mo2': 1.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8132715225219727
# Hand On Board!
# 0.8127310276031494
# 43
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0, 'w213': 2.0} {'mo2': -1.0, 'w213': 2.0, 'bsw27': 2.0} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {'mo2': 0.0, 'bsw27': 0.0} {}
# {'b64': 0.0} {'b64': 1.0, 'w223': 2.0} {'bsw24': 2.0, 'w223': 2.0} {'bsw24': 0.0} {'bsw24': 2.0, 'w228': 2.0} {'mo2': 1.0, 'bsw27': 2.0, 'w228': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7874205112457275
# 45
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0, 'w213': 2.0} {'mo2': -1.0, 'w213': 2.0} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {'mo2': 0.0} {}
# {'b64': 0.0} {'b64': 1.0, 'w223': 2.0} {'bsw24': 2.0, 'w223': 2.0} {'bsw24': 0.0} {'bsw24': 2.0, 'w228': 2.0} {'mo2': 1.0, 'w228': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# 50
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0, 'w213': 2.0} {'mo2': -1.0, 'w213': 2.0, 'bsw34': 2.0} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {'mo2': 0.0, 'bsw34': 0.0} {}
# {'b64': 0.0} {'b64': 1.0, 'w223': 2.0} {'bsw24': 2.0, 'w223': 2.0} {'bsw24': 0.0} {'bsw24': 2.0, 'w228': 2.0} {'mo2': 1.0, 'w228': 2.0, 'bsw34': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8694827556610107
# Hand On Board!
# 0.8776602745056152
# Hand On Board!
# 0.799126386642456
# Hand On Board!
# 0.7523224353790283
# Hand On Board!
# 0.7875628471374512
# 120
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0, 'w213': 2.0} {'mo2': -1.0, 'w213': 2.0} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {'mo2': 0.0} {}
# {'b64': 0.0} {'b64': 1.0, 'w223': 2.0} {'bsw24': 2.0, 'w223': 2.0} {'bsw24': 0.0} {'bsw24': 2.0, 'w228': 2.0} {'mo2': 1.0, 'w228': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# OUTPUTS:
# 0: b64 battery piece added 0.0 15,
# led1 led piece added 0.0 17,
# led2 led piece added 1.0 21,
# led1 led piece removed 1.0 21,
# w209 wire piece added 0.0 23,
# connection added 0.0 23,
# mo2 motor piece added 1.0 32,
# w213 wire piece added 1.0 32,
# connection added 1.0 32,
# bsw24 button_switch piece added 0.0 38,
# w223 wire piece added 0.0 40,
# connection added 0.0 40,
# bsw27 button_switch piece added 0.0 43,
# connection added 0.0 43,
# w228 wire piece added 0.0 43,
# connection added 0.0 43,
# closed added 0.0 43,
# led2 led StudType.POSITIVE stud_direction added 0.0 43,
# led2 led StudType.NEGATIVE stud_direction added 0.0 43,
# led2 led StudType.POSITIVE stud_direction added 0.0 43,
# led2 led StudType.NEGATIVE stud_direction added 0.0 43,
# led2 led StudType.POSITIVE stud_direction added 0.0 43,
# led2 led StudType.NEGATIVE stud_direction added 0.0 43,
# led2 led StudType.POSITIVE stud_direction added 0.0 43,
# led2 led StudType.NEGATIVE stud_direction added 0.0 43,
# led2 led StudType.POSITIVE stud_direction added 0.0 43,
# led2 led StudType.NEGATIVE stud_direction added 0.0 43,
# led2 led StudType.POSITIVE stud_direction added 0.0 43,
# led2 led StudType.NEGATIVE stud_direction added 0.0 43,
# parallel added 0.0 43,
# bsw27 button_switch piece removed 0.0 45,
# connection removed 0.0 45,
# bsw34 button_switch piece added 0.0 50,
# connection added 0.0 50,
# closed added 0.0 50,
# led2 led StudType.POSITIVE stud_direction added 0.0 50,
# led2 led StudType.NEGATIVE stud_direction added 0.0 50,
# led2 led StudType.POSITIVE stud_direction added 0.0 50,
# led2 led StudType.NEGATIVE stud_direction added 0.0 50,
# led2 led StudType.POSITIVE stud_direction added 0.0 50,
# led2 led StudType.NEGATIVE stud_direction added 0.0 50,
# led2 led StudType.POSITIVE stud_direction added 0.0 50,
# led2 led StudType.NEGATIVE stud_direction added 0.0 50,
# led2 led StudType.POSITIVE stud_direction added 0.0 50,
# led2 led StudType.NEGATIVE stud_direction added 0.0 50,
# led2 led StudType.POSITIVE stud_direction added 0.0 50,
# led2 led StudType.NEGATIVE stud_direction added 0.0 50,
# parallel added 0.0 50,
# bsw34 button_switch piece removed 1.0 120,
# connection removed 1.0 120,
#
# 1: b64 battery piece added 1.0 15,
# led1 led piece added 1.0 17,
# led2 led piece added 0.0 21,
# led1 led piece removed 0.0 21,
# w209 wire piece added 1.0 23,
# connection added 1.0 23,
# mo2 motor piece added 0.0 32,
# w213 wire piece added 0.0 32,
# connection added 0.0 32,
# bsw24 button_switch piece added 1.0 38,
# w223 wire piece added 1.0 40,
# connection added 1.0 40,
# bsw27 button_switch piece added 1.0 43,
# connection added 1.0 43,
# w228 wire piece added 1.0 43,
# connection added 1.0 43,
# closed added 1.0 43,
# led2 led StudType.POSITIVE stud_direction added 1.0 43,
# led2 led StudType.NEGATIVE stud_direction added 1.0 43,
# led2 led StudType.POSITIVE stud_direction added 1.0 43,
# led2 led StudType.NEGATIVE stud_direction added 1.0 43,
# led2 led StudType.POSITIVE stud_direction added 1.0 43,
# led2 led StudType.NEGATIVE stud_direction added 1.0 43,
# led2 led StudType.POSITIVE stud_direction added 1.0 43,
# led2 led StudType.NEGATIVE stud_direction added 1.0 43,
# led2 led StudType.POSITIVE stud_direction added 1.0 43,
# led2 led StudType.NEGATIVE stud_direction added 1.0 43,
# led2 led StudType.POSITIVE stud_direction added 1.0 43,
# led2 led StudType.NEGATIVE stud_direction added 1.0 43,
# parallel added 1.0 43,
# bsw27 button_switch piece removed 1.0 45,
# connection removed 1.0 45,
# bsw34 button_switch piece added 1.0 50,
# connection added 1.0 50,
# closed added 1.0 50,
# led2 led StudType.POSITIVE stud_direction added 1.0 50,
# led2 led StudType.NEGATIVE stud_direction added 1.0 50,
# led2 led StudType.POSITIVE stud_direction added 1.0 50,
# led2 led StudType.NEGATIVE stud_direction added 1.0 50,
# led2 led StudType.POSITIVE stud_direction added 1.0 50,
# led2 led StudType.NEGATIVE stud_direction added 1.0 50,
# led2 led StudType.POSITIVE stud_direction added 1.0 50,
# led2 led StudType.NEGATIVE stud_direction added 1.0 50,
# led2 led StudType.POSITIVE stud_direction added 1.0 50,
# led2 led StudType.NEGATIVE stud_direction added 1.0 50,
# led2 led StudType.POSITIVE stud_direction added 1.0 50,
# led2 led StudType.NEGATIVE stud_direction added 1.0 50,
# parallel added 1.0 50,
# bsw34 button_switch piece removed 0.0 120,
# connection removed 0.0 120,
#
#
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b64': 0.0} {'b64': -1.0, 'w209': 2.0} {'led2': -1.0, 'w209': 2.0} {'led2': 0.0} {'led2': 1.0, 'w213': 2.0} {'mo2': -1.0, 'w213': 2.0} {}
# {'b64': 0.0} {'b64': 0.0} {} {} {} {'mo2': 0.0} {}
# {'b64': 0.0} {'b64': 1.0, 'w223': 2.0} {'bsw24': 2.0, 'w223': 2.0} {'bsw24': 0.0} {'bsw24': 2.0, 'w228': 2.0} {'mo2': 1.0, 'w228': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}

# %%
if correct_init:
    print(unique_uids)
    valid_task, beliefs = mastery_updater.run_task(user_masteries, uids, unique_uids, source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size)
    if valid_task:
        user_masteries.move_to_next_task(beliefs)
# Out:
# [7, 8]
# Hand On Board!
# 0.8320622444152832
# Hand On Board!
# 0.8043873310089111
# Hand On Board!
# 0.8139674663543701
# Hand On Board!
# 0.8390500545501709
# 12
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b165': 0.0} {'b165': -1.0} {} {} {} {} {}
# {'b165': 0.0} {'b165': 0.0} {} {} {} {} {}
# {'b165': 0.0} {'b165': 1.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.795696496963501
# Hand On Board!
# 0.8048615455627441
# Hand On Board!
# 0.8207290172576904
# Hand On Board!
# 0.7831072807312012
# Hand On Board!
# 0.6748635768890381
# Hand On Board!
# 0.7212734222412109
# Hand On Board!
# 0.7250981330871582
# Hand On Board!
# 0.5870590209960938
# Hand On Board!
# 0.7613897323608398
# Hand On Board!
# 0.6426873207092285
# Hand On Board!
# 0.5944368839263916
# Hand On Board!
# 0.7192347049713135
# Hand On Board!
# 0.7745716571807861
# Hand On Board!
# 0.7360634803771973
# Hand On Board!
# 0.7003438472747803
# Hand On Board!
# 0.6548826694488525
# Hand On Board!
# 0.7988379001617432
# Hand On Board!
# 0.7244119644165039
# Hand On Board!
# 0.8256151676177979
# 33
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b165': 0.0} {'b165': -1.0} {'w569': 2.0} {'w569': 2.0} {'w569': 2.0} {'w569': 2.0} {'w569': 2.0}
# {'b165': 0.0} {'b165': 0.0} {} {} {} {} {}
# {'b165': 0.0} {'b165': 1.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7946169376373291
# Hand On Board!
# 0.7328591346740723
# Hand On Board!
# 0.7120974063873291
# Hand On Board!
# 0.7131223678588867
# Hand On Board!
# 0.719306468963623
# Hand On Board!
# 0.7397205829620361
# Hand On Board!
# 0.793065071105957
# Hand On Board!
# 0.7817647457122803
# 42
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b165': 0.0} {'b165': -1.0} {} {} {} {} {'w570': 2.0}
# {'b165': 0.0} {'b165': 0.0} {} {} {} {} {'la61': 2.0, 'w570': 2.0}
# {'b165': 0.0} {'b165': 1.0} {} {} {} {} {'la61': 0.0}
# {} {} {} {} {} {} {'la61': 2.0}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8097484111785889
# Hand On Board!
# 0.8346676826477051
# 45
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b165': 0.0} {'b165': -1.0} {} {} {} {} {'w570': 2.0}
# {'b165': 0.0} {'b165': 0.0} {} {} {} {} {'la61': 2.0, 'w570': 2.0}
# {'b165': 0.0} {'b165': 1.0} {} {} {} {} {'la61': 0.0}
# {} {} {} {} {} {} {'la61': 2.0, 'bsw121': 2.0}
# {} {} {} {} {} {} {'bsw121': 0.0}
# {} {} {} {} {} {} {'bsw121': 2.0}
#
# 46
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b165': 0.0} {'b165': -1.0} {'w573': 2.0} {'w573': 2.0} {'w573': 2.0} {'w573': 2.0} {'w570': 2.0, 'w573': 2.0}
# {'b165': 0.0} {'b165': 0.0} {} {} {} {} {'la61': 2.0, 'w570': 2.0}
# {'b165': 0.0} {'b165': 1.0} {} {} {} {} {'la61': 0.0}
# {} {} {} {} {} {} {'la61': 2.0, 'bsw121': 2.0}
# {} {} {} {} {} {} {'bsw121': 0.0}
# {} {} {} {} {} {} {'bsw121': 2.0}
#
# Hand On Board!
# 0.8082473278045654
# 48
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {'w570': 2.0}
# {} {} {} {} {'led99': 1.0} {} {'la61': 2.0, 'w570': 2.0}
# {} {} {} {} {'led99': 0.0} {} {'la61': 0.0}
# {} {} {} {} {'led99': -1.0} {} {'la61': 2.0, 'bsw121': 2.0}
# {} {} {} {} {} {} {'bsw121': 0.0}
# {} {} {} {} {} {} {'bsw121': 2.0}
#
# Hand On Board!
# 0.7248373031616211
# 50
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b170': 0.0} {'b170': -1.0} {} {'w577': 2.0} {'w575': 2.0, 'w577': 2.0} {'w577': 2.0} {'w570': 2.0, 'w577': 2.0}
# {'b170': 0.0} {'b170': 0.0} {} {} {'led99': 1.0, 'w575': 2.0} {} {'la61': 2.0, 'w570': 2.0}
# {'b170': 0.0} {'b170': 1.0} {} {} {'led99': 0.0} {} {'la61': 0.0}
# {} {} {} {} {'led99': -1.0} {} {'la61': 2.0, 'bsw121': 2.0}
# {} {} {} {} {} {} {'bsw121': 0.0}
# {} {} {} {} {} {} {'bsw121': 2.0}
#
# Hand On Board!
# 0.810882568359375
# Hand On Board!
# 0.7314450740814209
# Hand On Board!
# 0.7399992942810059
# Hand On Board!
# 0.7107148170471191
# Hand On Board!
# 0.739945650100708
# Hand On Board!
# 0.6923127174377441
# Hand On Board!
# 0.8287498950958252
# Hand On Board!
# 0.7584125995635986
# Hand On Board!
# 0.68892502784729
# Hand On Board!
# 0.6705634593963623
# 64
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b170': 0.0} {'b170': -1.0} {} {'w577': 2.0} {'w575': 2.0, 'w577': 2.0} {'w577': 2.0} {'w570': 2.0, 'w577': 2.0}
# {'b170': 0.0} {'b170': 0.0} {} {} {'led99': 1.0, 'w575': 2.0} {} {'la61': 2.0, 'w570': 2.0}
# {'b170': 0.0} {'b170': 1.0} {} {} {'led99': 0.0} {} {'la61': 0.0}
# {} {} {} {} {'led99': -1.0, 'sw57': 2.0} {} {'la61': 2.0, 'bsw121': 2.0}
# {} {} {} {} {'sw57': 0.0} {} {'bsw121': 0.0}
# {} {} {} {} {'sw57': 2.0, 'w590': 2.0} {'w590': 2.0} {'bsw121': 2.0, 'w590': 2.0}
#
# 65
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b170': 0.0} {'b170': -1.0} {} {'w577': 2.0} {'w575': 2.0, 'w577': 2.0} {'w577': 2.0} {'w570': 2.0, 'w577': 2.0}
# {'b170': 0.0} {'b170': 0.0} {} {} {'led99': 1.0, 'w575': 2.0} {} {'la61': 2.0, 'w570': 2.0}
# {'b170': 0.0} {'b170': 1.0} {} {} {'led99': 0.0} {} {'la61': 0.0}
# {} {} {} {} {'led99': -1.0, 'sw57': 2.0} {} {'la61': 2.0, 'bsw121': 2.0}
# {} {} {} {} {'sw57': 0.0} {} {'bsw121': 0.0}
# {} {'w594': 2.0} {'w594': 2.0} {'w594': 2.0} {'sw57': 2.0, 'w590': 2.0, 'w594': 2.0} {'w590': 2.0} {'bsw121': 2.0, 'w590': 2.0}
#
# Hand On Board!
# 0.8062036037445068
# Hand On Board!
# 0.7969701290130615
# Hand On Board!
# 0.7298433780670166
# Hand On Board!
# 0.7436237335205078
# Hand On Board!
# 0.7610313892364502
# Hand On Board!
# 0.796236515045166
# 72
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b170': 0.0} {'b170': -1.0, 'w598': 2.0} {'w598': 2.0} {'w598': 2.0} {'w598': 2.0} {} {'w596': 2.0}
# {'b170': 0.0} {'b170': 0.0} {} {} {} {} {'w596': 2.0}
# {'b170': 0.0} {'b170': 1.0, 'w595': 2.0} {} {} {} {} {'w596': 2.0}
# {} {'w595': 2.0} {} {} {} {} {'bsw121': 2.0, 'w596': 2.0}
# {} {'w595': 2.0} {} {} {} {} {'bsw121': 0.0}
# {} {'w595': 2.0, 'w597': 2.0} {'w597': 2.0} {'w597': 2.0} {} {} {'bsw121': 2.0}
#
# Hand On Board!
# 0.8430647850036621
# Hand On Board!
# 0.8094227313995361
# Hand On Board!
# 0.7331390380859375
# Hand On Board!
# 0.6522281169891357
# Hand On Board!
# 0.6179037094116211
# Hand On Board!
# 0.651282787322998
# Hand On Board!
# 0.8409574031829834
# Hand On Board!
# 0.6771748065948486
# Hand On Board!
# 0.7908351421356201
# Hand On Board!
# 0.7906029224395752
# Hand On Board!
# 0.7856400012969971
# Hand On Board!
# 0.694450855255127
# Hand On Board!
# 0.7999863624572754
# Hand On Board!
# 0.7857754230499268
# 87
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b170': 0.0} {'b170': -1.0, 'w604': 2.0} {'w604': 2.0} {'w604': 2.0} {'w600': 2.0, 'w604': 2.0} {'w604': 2.0} {'w601': 2.0, 'w604': 2.0}
# {'b170': 0.0} {'b170': 0.0} {} {} {'led106': -1.0, 'w600': 2.0} {} {'la71': 2.0, 'w601': 2.0}
# {'b170': 0.0} {'b170': 1.0, 'w595': 2.0} {} {} {'led106': 0.0} {} {'la71': 0.0}
# {} {'w595': 2.0} {} {} {'led106': 1.0, 'sw59': 2.0} {} {'bsw121': 2.0, 'la71': 2.0}
# {} {'w595': 2.0} {} {} {'sw59': 0.0} {} {'bsw121': 0.0}
# {} {'w595': 2.0, 'w602': 2.0} {'w602': 2.0} {'w602': 2.0} {'sw59': 2.0, 'w602': 2.0, 'w603': 2.0} {'w603': 2.0} {'bsw121': 2.0, 'w603': 2.0}
#
# 89
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b170': 0.0} {'b170': -1.0, 'w604': 2.0} {'w604': 2.0} {'w604': 2.0, 'w617': 2.0} {'w600': 2.0, 'w604': 2.0, 'w617': 2.0} {'w604': 2.0, 'w617': 2.0} {'w601': 2.0, 'w604': 2.0, 'w617': 2.0}
# {'b170': 0.0} {'b170': 0.0} {} {} {'led106': -1.0, 'w600': 2.0} {} {'la71': 2.0, 'w601': 2.0}
# {'b170': 0.0} {'b170': 1.0, 'w595': 2.0} {} {} {'led106': 0.0} {} {'la71': 0.0}
# {} {'w595': 2.0} {} {} {'led106': 1.0, 'sw59': 2.0} {} {'bsw121': 2.0, 'la71': 2.0}
# {} {'w595': 2.0} {} {} {'sw59': 0.0} {} {'bsw121': 0.0}
# {} {'w595': 2.0, 'w602': 2.0} {'w602': 2.0} {'w602': 2.0} {'sw59': 2.0, 'w602': 2.0, 'w603': 2.0} {'w603': 2.0} {'bsw121': 2.0, 'w603': 2.0}
#
# 96
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b170': 0.0} {'b170': -1.0, 'w604': 2.0} {'w604': 2.0, 'w661': 2.0} {'w604': 2.0, 'w617': 2.0, 'w661': 2.0} {'w600': 2.0, 'w604': 2.0, 'w617': 2.0, 'w661': 2.0} {'w604': 2.0, 'w617': 2.0, 'w661': 2.0} {'w601': 2.0, 'w604': 2.0, 'w617': 2.0, 'w661': 2.0}
# {'b170': 0.0} {'b170': 0.0} {} {} {'led106': -1.0, 'w600': 2.0} {} {'la71': 2.0, 'w601': 2.0}
# {'b170': 0.0} {'b170': 1.0, 'w595': 2.0} {} {} {'led106': 0.0} {} {'la71': 0.0}
# {} {'w595': 2.0} {} {} {'led106': 1.0, 'sw59': 2.0} {} {'bsw121': 2.0, 'la71': 2.0}
# {} {'w595': 2.0} {} {} {'sw59': 0.0} {} {'bsw121': 0.0}
# {} {'w595': 2.0, 'w602': 2.0} {'w602': 2.0} {'w602': 2.0} {'sw59': 2.0, 'w602': 2.0, 'w603': 2.0} {'w603': 2.0} {'bsw121': 2.0, 'w603': 2.0}
#
# OUTPUTS:
# 0: b165 battery piece added 1.0 12,
# w569 wire piece added 0.43478260869565216 33,
# la61 lamp piece added 0.625 42,
# w570 wire piece added 0.625 42,
# connection added 0.625 42,
# w569 wire piece removed 0.625 42,
# connection removed 0.625 42,
# bsw121 button_switch piece added 0.0 45,
# connection added 0.0 45,
# w573 wire piece added 0.0 46,
# connection added 0.0 46,
# led99 led piece added 1.0 48,
# b165 battery piece removed 1.0 48,
# w573 wire piece removed 1.0 48,
# connection removed 1.0 48,
# b170 battery piece added 1.0 50,
# w575 wire piece added 1.0 50,
# connection added 1.0 50,
# w577 wire piece added 1.0 50,
# connection added 1.0 50,
# sw57 switch piece added 0.8 64,
# connection added 0.8 64,
# w590 wire piece added 0.8 64,
# connection added 0.8 64,
# w594 wire piece added 0.8 65,
# connection added 0.8 65,
# w595 wire piece added 1.0 72,
# connection added 1.0 72,
# w596 wire piece added 1.0 72,
# connection added 1.0 72,
# w597 wire piece added 1.0 72,
# connection added 1.0 72,
# w598 wire piece added 1.0 72,
# connection added 1.0 72,
# closed added 1.0 72,
# parallel added 1.0 72,
# la61 lamp piece removed 1.0 72,
# connection removed 1.0 72,
# w570 wire piece removed 1.0 72,
# connection removed 1.0 72,
# led99 led piece removed 1.0 72,
# connection removed 1.0 72,
# w575 wire piece removed 1.0 72,
# connection removed 1.0 72,
# w577 wire piece removed 1.0 72,
# connection removed 1.0 72,
# sw57 switch piece removed 1.0 72,
# connection removed 1.0 72,
# w590 wire piece removed 1.0 72,
# connection removed 1.0 72,
# w594 wire piece removed 1.0 72,
# connection removed 1.0 72,
# la71 lamp piece added 0.35294117647058826 87,
# connection added 0.35294117647058826 87,
# led106 led piece added 0.35294117647058826 87,
# sw59 switch piece added 0.35294117647058826 87,
# connection added 0.35294117647058826 87,
# w600 wire piece added 0.35294117647058826 87,
# connection added 0.35294117647058826 87,
# w601 wire piece added 0.35294117647058826 87,
# connection added 0.35294117647058826 87,
# w602 wire piece added 0.35294117647058826 87,
# connection added 0.35294117647058826 87,
# closed added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# parallel added 0.35294117647058826 87,
# w603 wire piece added 0.35294117647058826 87,
# connection added 0.35294117647058826 87,
# closed added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# parallel added 0.35294117647058826 87,
# w604 wire piece added 0.35294117647058826 87,
# connection added 0.35294117647058826 87,
# closed added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 87,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 87,
# parallel added 0.35294117647058826 87,
# w596 wire piece removed 0.35294117647058826 87,
# connection removed 0.35294117647058826 87,
# w597 wire piece removed 0.35294117647058826 87,
# connection removed 0.35294117647058826 87,
# w598 wire piece removed 0.35294117647058826 87,
# connection removed 0.35294117647058826 87,
# w617 wire piece added 0.35294117647058826 89,
# connection added 0.35294117647058826 89,
# closed added 0.35294117647058826 89,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 89,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 89,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 89,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 89,
# parallel added 0.35294117647058826 89,
# w661 wire piece added 0.35294117647058826 96,
# connection added 0.35294117647058826 96,
# closed added 0.35294117647058826 96,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 96,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 96,
# led106 led StudType.POSITIVE stud_direction added 0.35294117647058826 96,
# led106 led StudType.NEGATIVE stud_direction added 0.35294117647058826 96,
# parallel added 0.35294117647058826 96,
#
# 1: b165 battery piece added 0.0 12,
# w569 wire piece added 0.5652173913043478 33,
# la61 lamp piece added 0.375 42,
# w570 wire piece added 0.375 42,
# connection added 0.375 42,
# w569 wire piece removed 0.375 42,
# connection removed 0.375 42,
# bsw121 button_switch piece added 1.0 45,
# connection added 1.0 45,
# w573 wire piece added 1.0 46,
# connection added 1.0 46,
# led99 led piece added 0.0 48,
# b165 battery piece removed 0.0 48,
# w573 wire piece removed 0.0 48,
# connection removed 0.0 48,
# b170 battery piece added 0.0 50,
# w575 wire piece added 0.0 50,
# connection added 0.0 50,
# w577 wire piece added 0.0 50,
# connection added 0.0 50,
# sw57 switch piece added 0.2 64,
# connection added 0.2 64,
# w590 wire piece added 0.2 64,
# connection added 0.2 64,
# w594 wire piece added 0.2 65,
# connection added 0.2 65,
# w595 wire piece added 0.0 72,
# connection added 0.0 72,
# w596 wire piece added 0.0 72,
# connection added 0.0 72,
# w597 wire piece added 0.0 72,
# connection added 0.0 72,
# w598 wire piece added 0.0 72,
# connection added 0.0 72,
# closed added 0.0 72,
# parallel added 0.0 72,
# la61 lamp piece removed 0.0 72,
# connection removed 0.0 72,
# w570 wire piece removed 0.0 72,
# connection removed 0.0 72,
# led99 led piece removed 0.0 72,
# connection removed 0.0 72,
# w575 wire piece removed 0.0 72,
# connection removed 0.0 72,
# w577 wire piece removed 0.0 72,
# connection removed 0.0 72,
# sw57 switch piece removed 0.0 72,
# connection removed 0.0 72,
# w590 wire piece removed 0.0 72,
# connection removed 0.0 72,
# w594 wire piece removed 0.0 72,
# connection removed 0.0 72,
# la71 lamp piece added 0.6470588235294118 87,
# connection added 0.6470588235294118 87,
# led106 led piece added 0.6470588235294118 87,
# sw59 switch piece added 0.6470588235294118 87,
# connection added 0.6470588235294118 87,
# w600 wire piece added 0.6470588235294118 87,
# connection added 0.6470588235294118 87,
# w601 wire piece added 0.6470588235294118 87,
# connection added 0.6470588235294118 87,
# w602 wire piece added 0.6470588235294118 87,
# connection added 0.6470588235294118 87,
# closed added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# parallel added 0.6470588235294118 87,
# w603 wire piece added 0.6470588235294118 87,
# connection added 0.6470588235294118 87,
# closed added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# parallel added 0.6470588235294118 87,
# w604 wire piece added 0.6470588235294118 87,
# connection added 0.6470588235294118 87,
# closed added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 87,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 87,
# parallel added 0.6470588235294118 87,
# w596 wire piece removed 0.6470588235294118 87,
# connection removed 0.6470588235294118 87,
# w597 wire piece removed 0.6470588235294118 87,
# connection removed 0.6470588235294118 87,
# w598 wire piece removed 0.6470588235294118 87,
# connection removed 0.6470588235294118 87,
# w617 wire piece added 0.6470588235294118 89,
# connection added 0.6470588235294118 89,
# closed added 0.6470588235294118 89,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 89,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 89,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 89,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 89,
# parallel added 0.6470588235294118 89,
# w661 wire piece added 0.6470588235294118 96,
# connection added 0.6470588235294118 96,
# closed added 0.6470588235294118 96,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 96,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 96,
# led106 led StudType.POSITIVE stud_direction added 0.6470588235294118 96,
# led106 led StudType.NEGATIVE stud_direction added 0.6470588235294118 96,
# parallel added 0.6470588235294118 96,
#
#
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {'b170': 0.0} {'b170': -1.0, 'w604': 2.0} {'w604': 2.0, 'w661': 2.0} {'w604': 2.0, 'w617': 2.0, 'w661': 2.0} {'w600': 2.0, 'w604': 2.0, 'w617': 2.0, 'w661': 2.0} {'w604': 2.0, 'w617': 2.0, 'w661': 2.0} {'w601': 2.0, 'w604': 2.0, 'w617': 2.0, 'w661': 2.0}
# {'b170': 0.0} {'b170': 0.0} {} {} {'led106': -1.0, 'w600': 2.0} {} {'la71': 2.0, 'w601': 2.0}
# {'b170': 0.0} {'b170': 1.0, 'w595': 2.0} {} {} {'led106': 0.0} {} {'la71': 0.0}
# {} {'w595': 2.0} {} {} {'led106': 1.0, 'sw59': 2.0} {} {'bsw121': 2.0, 'la71': 2.0}
# {} {'w595': 2.0} {} {} {'sw59': 0.0} {} {'bsw121': 0.0}
# {} {'w595': 2.0, 'w602': 2.0} {'w602': 2.0} {'w602': 2.0} {'sw59': 2.0, 'w602': 2.0, 'w603': 2.0} {'w603': 2.0} {'bsw121': 2.0, 'w603': 2.0}

# %%
if correct_init:
    print(unique_uids)
    valid_task, beliefs = mastery_updater.run_task(user_masteries, uids, unique_uids, source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size)
    if valid_task:
        user_masteries.move_to_next_task(beliefs)
# Out:
# [7, 8]
# Hand On Board!
# 0.7358016967773438
# Hand On Board!
# 0.728219747543335
# Hand On Board!
# 0.7645363807678223
# Hand On Board!
# 0.8067982196807861
# Hand On Board!
# 0.8065187931060791
# Hand On Board!
# 0.681891679763794
# Hand On Board!
# 0.8326420783996582
# Hand On Board!
# 0.858802318572998
# Hand On Board!
# 0.8826370239257812
# 28
# {'b336': 0.0} {'b336': -1.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7998580932617188
# Hand On Board!
# 0.6164989471435547
# Hand On Board!
# 0.604050874710083
# Hand On Board!
# 0.5847885608673096
# Hand On Board!
# 0.768129825592041
# Hand On Board!
# 0.7994704246520996
# Hand On Board!
# 0.8240189552307129
# 36
# {'b336': 0.0} {'b336': -1.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0} {} {} {} {} {}
# {'mc1': 6.0} {'mc1': 3.0} {} {} {} {} {}
# {'mc1': 5.0} {'mc1': 0.0} {} {} {} {} {}
# {'mc1': 7.0} {'mc1': 4.0} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.6887130737304688
# 38
# {'b336': 0.0} {'b336': -1.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 6.0} {'mc1': 3.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 5.0} {'mc1': 0.0} {} {} {} {} {}
# {'mc1': 7.0} {'mc1': 4.0} {'sp1': 2.0} {'sp1': 0.0} {'sp1': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# 40
# {'b336': 0.0} {'b336': -1.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 6.0} {'mc1': 3.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 5.0} {'mc1': 0.0} {} {} {} {} {}
# {'mc1': 7.0} {'mc1': 4.0, 'w1592': 2.0} {'sp1': 2.0, 'w1592': 2.0} {'sp1': 0.0} {'sp1': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8037562370300293
# Hand On Board!
# 0.6203830242156982
# Hand On Board!
# 0.7110185623168945
# 44
# {'b336': 0.0} {'b336': -1.0} {'bsw290': 2.0, 'sw218': 2.0} {'bsw290': 0.0, 'sw218': 0.0} {'bsw290': 2.0, 'sw218': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 6.0} {'mc1': 3.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 5.0} {'mc1': 0.0} {} {} {} {} {}
# {'mc1': 7.0} {'mc1': 4.0, 'w1592': 2.0} {'sp1': 2.0, 'w1592': 2.0} {'sp1': 0.0} {'sp1': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.768101692199707
# 46
# {'b336': 0.0} {'b336': -1.0} {'sw218': 2.0} {'sw218': 0.0} {'sw218': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 6.0} {'mc1': 3.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 5.0} {'mc1': 0.0} {} {} {} {} {}
# {'mc1': 7.0} {'mc1': 4.0, 'w1592': 2.0} {'sp1': 2.0, 'w1592': 2.0} {'sp1': 0.0} {'sp1': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7960858345031738
# Hand On Board!
# 0.8563439846038818
# 49
# {'b336': 0.0} {'b336': -1.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1589': 2.0} {} {} {} {} {}
# {'mc1': 6.0} {'mc1': 3.0, 'w1589': 2.0} {} {} {'w1599': 2.0} {} {}
# {'mc1': 5.0} {'mc1': 0.0} {} {} {'w1599': 2.0} {} {}
# {'mc1': 7.0} {'mc1': 4.0, 'w1592': 2.0} {'sp1': 2.0, 'w1592': 2.0} {'sp1': 0.0} {'sp1': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8137009143829346
# 51
# {'b336': 0.0} {'b336': -1.0} {'sw220': 2.0} {'sw220': 0.0} {'sw220': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1601': 2.0} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1589': 2.0} {} {} {'w1601': 2.0} {} {}
# {'mc1': 6.0} {'mc1': 3.0, 'w1589': 2.0} {} {} {'w1601': 2.0} {} {}
# {'mc1': 5.0} {'mc1': 0.0} {} {} {'w1601': 2.0} {} {}
# {'mc1': 7.0} {'mc1': 4.0, 'w1592': 2.0} {'sp1': 2.0, 'w1592': 2.0} {'sp1': 0.0} {'sp1': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8050971031188965
# Hand On Board!
# 0.7926628589630127
# Hand On Board!
# 0.6919429302215576
# Hand On Board!
# 0.6980767250061035
# Hand On Board!
# 0.8251428604125977
# Hand On Board!
# 0.7832977771759033
# Hand On Board!
# 0.6871151924133301
# Hand On Board!
# 0.6194560527801514
# Hand On Board!
# 0.706641435623169
# Hand On Board!
# 0.8214607238769531
# Hand On Board!
# 0.85809326171875
# Hand On Board!
# 0.8021719455718994
# Hand On Board!
# 0.7978570461273193
# Hand On Board!
# 0.629751443862915
# Hand On Board!
# 0.7396054267883301
# Hand On Board!
# 0.8279953002929688
# Hand On Board!
# 0.7440073490142822
# Hand On Board!
# 0.6955254077911377
# Hand On Board!
# 0.6045277118682861
# 71
# {'b336': 0.0} {'b336': -1.0, 'sp9': 2.0} {'sw220': 2.0, 'sp9': 0.0} {'sw220': 0.0, 'sp9': 2.0} {'sw220': 2.0, 'w1603': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1603': 2.0} {} {}
# {'b336': 0.0} {'b336': 1.0} {} {} {'w1603': 2.0} {} {}
# {} {} {} {} {'w1603': 2.0} {} {}
# {} {} {} {} {'w1603': 2.0, 'w1604': 2.0} {} {}
# {} {} {'sp1': 2.0} {'sp1': 0.0} {'sp1': 2.0, 'w1604': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# 72
# {'b336': 0.0} {'b336': -1.0, 'sp9': 2.0, 'w1607': 2.0} {'sw220': 2.0, 'sp9': 0.0, 'w1607': 2.0} {'sw220': 0.0, 'sp9': 2.0} {'sw220': 2.0, 'w1603': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1603': 2.0} {} {}
# {'b336': 0.0} {'b336': 1.0} {} {} {'w1603': 2.0} {} {}
# {} {} {} {} {'w1603': 2.0} {} {}
# {} {} {} {} {'w1603': 2.0, 'w1604': 2.0} {} {}
# {} {} {'sp1': 2.0} {'sp1': 0.0} {'sp1': 2.0, 'w1604': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8141000270843506
# Hand On Board!
# 0.7654061317443848
# Hand On Board!
# 0.7384634017944336
# Hand On Board!
# 0.8177211284637451
# Hand On Board!
# 0.706794023513794
# Hand On Board!
# 0.4434363842010498
# 80
# {'b336': 0.0} {'b336': -1.0, 'w1607': 2.0} {'sw220': 2.0, 'w1607': 2.0} {'sw220': 0.0} {'sw220': 2.0, 'w1603': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1603': 2.0} {} {}
# {'b336': 0.0} {'b336': 1.0} {} {} {'w1603': 2.0} {} {}
# {} {} {} {} {'w1603': 2.0} {} {}
# {} {} {} {} {'w1603': 2.0, 'w1604': 2.0} {} {}
# {} {} {'sp1': 2.0} {'sp1': 0.0} {'sp1': 2.0, 'w1604': 2.0} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7170379161834717
# Hand On Board!
# 0.6528024673461914
# Hand On Board!
# 0.6697862148284912
# Hand On Board!
# 0.6142213344573975
# Hand On Board!
# 0.778832197189331
# Hand On Board!
# 0.7273719310760498
# Hand On Board!
# 0.715604305267334
# Hand On Board!
# 0.6456892490386963
# Hand On Board!
# 0.6469728946685791
# Hand On Board!
# 0.7454757690429688
# Hand On Board!
# 0.6474051475524902
# Hand On Board!
# 0.7769021987915039
# Hand On Board!
# 0.7294707298278809
# Hand On Board!
# 0.7507071495056152
# Hand On Board!
# 0.5544388294219971
# Hand On Board!
# 0.7064542770385742
# Hand On Board!
# 0.7149968147277832
# 98
# {'b336': 0.0} {'b336': -1.0} {} {} {} {} {'sp13': 2.0}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {'sp13': 0.0}
# {'b336': 0.0} {'b336': 1.0} {} {} {'mc9': 6.0} {'mc9': 3.0} {'sp13': 2.0}
# {} {'sw225': 2.0} {'sw225': 0.0} {'sw225': 2.0} {'mc9': 5.0} {'mc9': 0.0} {}
# {} {} {} {} {'mc9': 7.0} {'mc9': 4.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8259327411651611
# 100
# {'b336': 0.0} {'b336': -1.0} {'w1614': 2.0} {'w1614': 2.0} {'w1614': 2.0} {} {'sp13': 2.0}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {'sp13': 0.0}
# {'b336': 0.0} {'b336': 1.0} {} {} {'mc9': 6.0} {'mc9': 3.0} {'sp13': 2.0}
# {} {'sw225': 2.0} {'sw225': 0.0} {'sw225': 2.0} {'mc9': 5.0} {'mc9': 0.0} {}
# {} {} {} {} {'mc9': 7.0} {'mc9': 4.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8077678680419922
# Hand On Board!
# 0.5860333442687988
# Hand On Board!
# 0.6049134731292725
# Hand On Board!
# 0.8148534297943115
# 105
# {'b336': 0.0} {'b336': -1.0} {'w1614': 2.0} {'w1614': 2.0} {'w1614': 2.0} {} {'sp13': 2.0}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {'sp13': 0.0}
# {'b336': 0.0} {'b336': 1.0} {} {} {'mc9': 6.0} {'mc9': 3.0} {'sp13': 2.0}
# {} {'sw225': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'mc9': 5.0, 'w1615': 2.0} {'mc9': 0.0} {}
# {} {} {} {} {'mc9': 7.0} {'mc9': 4.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.8014156818389893
# Hand On Board!
# 0.5900137424468994
# Hand On Board!
# 0.6091206073760986
# Hand On Board!
# 0.516268253326416
# Hand On Board!
# 0.6719446182250977
# 111
# {'b336': 0.0} {'b336': -1.0} {'w1614': 2.0} {'w1614': 2.0} {'w1614': 2.0, 'w1619': 2.0} {} {'sp13': 2.0}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1619': 2.0} {} {'sp13': 0.0}
# {'b336': 0.0} {'b336': 1.0} {} {} {'mc9': 6.0, 'w1619': 2.0} {'mc9': 3.0} {'sp13': 2.0}
# {} {'sw225': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'mc9': 5.0, 'w1615': 2.0} {'mc9': 0.0} {}
# {} {} {} {} {'mc9': 7.0} {'mc9': 4.0, 'w1618': 2.0} {}
# {} {'w1620': 2.0} {'w1620': 2.0} {'w1620': 2.0} {'w1620': 2.0} {'w1618': 2.0, 'w1620': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7835385799407959
# Hand On Board!
# 0.6549019813537598
# Hand On Board!
# 0.7209722995758057
# Hand On Board!
# 0.8159141540527344
# Hand On Board!
# 0.7844443321228027
# Hand On Board!
# 0.7311341762542725
# Hand On Board!
# 0.65334153175354
# Hand On Board!
# 0.44826197624206543
# Hand On Board!
# 0.7377383708953857
# Hand On Board!
# 0.7809796333312988
# Hand On Board!
# 0.7869141101837158
# 124
# {'b336': 0.0} {'b336': -1.0} {'w1614': 2.0} {'w1614': 2.0} {'w1614': 2.0, 'w1619': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1619': 2.0} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1627': 2.0} {} {} {'mc9': 6.0, 'w1619': 2.0} {'mc9': 3.0} {}
# {} {'sw225': 2.0, 'w1627': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'mc9': 5.0, 'w1615': 2.0} {'mc9': 0.0} {}
# {} {} {} {} {'mc9': 7.0} {'mc9': 4.0, 'w1618': 2.0} {}
# {} {} {} {'sp18': 2.0} {'sp18': 0.0} {'w1618': 2.0, 'sp18': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# 125
# {'b336': 0.0} {'b336': -1.0} {'w1614': 2.0} {'w1614': 2.0} {'w1614': 2.0, 'w1619': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1619': 2.0} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1627': 2.0} {} {} {'mc9': 6.0, 'w1619': 2.0} {'mc9': 3.0} {}
# {} {'sw225': 2.0, 'w1627': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'mc9': 5.0, 'w1615': 2.0} {'mc9': 0.0} {}
# {} {} {} {} {'mc9': 7.0} {'mc9': 4.0, 'w1618': 2.0} {}
# {} {'w1635': 2.0} {'w1635': 2.0} {'sp18': 2.0} {'sp18': 0.0} {'w1618': 2.0, 'sp18': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.9063751697540283
# Hand On Board!
# 0.7103207111358643
# Hand On Board!
# 0.7270615100860596
# Hand On Board!
# 0.7090206146240234
# Hand On Board!
# 0.6313354969024658
# Hand On Board!
# 0.5747668743133545
# Hand On Board!
# 0.6591517925262451
# Hand On Board!
# 0.5488653182983398
# Hand On Board!
# 0.6457953453063965
# 135
# {'b336': 0.0} {'b336': -1.0} {'w1614': 2.0, 'w1643': 2.0} {'w1614': 2.0, 'w1643': 2.0} {'w1614': 2.0, 'w1619': 2.0, 'sp21': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1619': 2.0, 'sp21': 0.0} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1627': 2.0} {} {} {'mc9': 6.0, 'w1619': 2.0, 'sp21': 2.0} {'mc9': 3.0} {}
# {} {'sw225': 2.0, 'w1627': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'mc9': 5.0, 'w1615': 2.0} {'mc9': 0.0} {}
# {} {} {} {} {'mc9': 7.0} {'mc9': 4.0, 'w1618': 2.0} {}
# {} {'w1641': 2.0} {'w1641': 2.0} {'sp18': 2.0, 'w1641': 2.0} {'sp18': 0.0} {'w1618': 2.0, 'sp18': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.6858389377593994
# Hand On Board!
# 0.7097091674804688
# Hand On Board!
# 0.6332962512969971
# Hand On Board!
# 0.745302677154541
# 140
# {'b336': 0.0} {'b336': -1.0} {'w1614': 2.0} {'w1614': 2.0} {'w1614': 2.0, 'w1619': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1619': 2.0} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1627': 2.0} {} {} {'mc9': 6.0, 'w1619': 2.0} {'mc9': 3.0} {}
# {} {'sw225': 2.0, 'w1627': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'mc9': 5.0, 'w1615': 2.0} {'mc9': 0.0} {}
# {} {} {} {} {'mc9': 7.0} {'mc9': 4.0, 'w1618': 2.0} {}
# {} {'w1648': 2.0} {} {'sp18': 2.0} {'sp18': 0.0} {'w1618': 2.0, 'sp18': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# 141
# {'b336': 0.0} {'b336': -1.0} {'w1614': 2.0} {'w1614': 2.0} {'w1614': 2.0, 'w1619': 2.0} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {'w1619': 2.0} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1627': 2.0} {} {} {'mc9': 6.0, 'w1619': 2.0, 'mc18': 4.0} {'mc9': 3.0, 'mc18': 7.0} {}
# {} {'sw225': 2.0, 'w1627': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'mc9': 5.0, 'w1615': 2.0, 'mc18': 0.0} {'mc9': 0.0, 'mc18': 5.0} {}
# {} {} {} {} {'mc9': 7.0, 'mc18': 3.0} {'mc9': 4.0, 'w1618': 2.0, 'mc18': 6.0} {}
# {} {'w1648': 2.0} {} {'sp18': 2.0} {'sp18': 0.0} {'w1618': 2.0, 'sp18': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.9175388813018799
# Hand On Board!
# 0.8156754970550537
# Hand On Board!
# 0.7217333316802979
# Hand On Board!
# 0.6873676776885986
# Hand On Board!
# 0.7300071716308594
# Hand On Board!
# 0.696868896484375
# Hand On Board!
# 0.7081716060638428
# Hand On Board!
# 0.6599271297454834
# 151
# {'b336': 0.0} {'b336': -1.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1664': 2.0} {} {} {'mc18': 4.0} {'mc18': 7.0} {}
# {} {'sw225': 2.0, 'w1664': 2.0, 'w1667': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'w1615': 2.0, 'mc18': 0.0} {'mc18': 5.0} {}
# {} {'w1664': 2.0, 'w1667': 2.0} {} {} {'mc18': 3.0} {'w1618': 2.0, 'mc18': 6.0} {}
# {} {'w1664': 2.0, 'w1665': 2.0, 'w1667': 2.0} {'w1665': 2.0} {'sp18': 2.0, 'w1665': 2.0} {'sp18': 0.0} {'w1618': 2.0, 'sp18': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7970218658447266
# Hand On Board!
# 0.6257228851318359
# Hand On Board!
# 0.6392583847045898
# 155
# {'b336': 0.0} {'b336': -1.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {} {}
# {'b336': 0.0} {'b336': 1.0, 'w1664': 2.0} {} {} {'mc21': 6.0} {'mc21': 3.0} {}
# {} {'sw225': 2.0, 'w1664': 2.0, 'w1667': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'w1615': 2.0, 'mc21': 5.0} {'mc21': 0.0} {}
# {} {'w1664': 2.0, 'w1667': 2.0} {} {} {'mc21': 7.0} {'w1618': 2.0, 'mc21': 4.0} {}
# {} {'w1664': 2.0, 'w1665': 2.0, 'w1667': 2.0} {'w1665': 2.0} {'sp18': 2.0, 'w1665': 2.0} {'sp18': 0.0} {'w1618': 2.0, 'sp18': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.6857550144195557
# Hand On Board!
# 0.5783953666687012
# Hand On Board!
# 0.78053879737854
# Hand On Board!
# 0.6830675601959229
# Hand On Board!
# 0.6640088558197021
# Hand On Board!
# 0.7243368625640869
# Hand On Board!
# 0.6195156574249268
# Hand On Board!
# 0.6813108921051025
# Hand On Board!
# 0.7254593372344971
# Hand On Board!
# 0.651655912399292
# Hand On Board!
# 0.6086235046386719
# Hand On Board!
# 0.6362278461456299
# Hand On Board!
# 0.6386685371398926
# Hand On Board!
# 0.5322091579437256
# Hand On Board!
# 0.8448421955108643
# 171
# {'b336': 0.0} {'b336': -1.0, 'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0, 'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 1.0, 'w1664': 2.0} {} {} {'mc21': 6.0} {'mc21': 3.0, 'w1678': 2.0} {}
# {} {'sw225': 2.0, 'w1664': 2.0, 'w1667': 2.0} {'sw225': 0.0} {'sw225': 2.0, 'w1615': 2.0} {'w1615': 2.0, 'mc21': 5.0} {'mc21': 0.0} {}
# {} {'w1664': 2.0, 'w1667': 2.0} {} {} {'mc21': 7.0} {'w1618': 2.0, 'mc21': 4.0} {}
# {} {'w1664': 2.0, 'w1665': 2.0, 'w1667': 2.0} {'w1665': 2.0} {'sp18': 2.0, 'w1665': 2.0} {'sp18': 0.0} {'w1618': 2.0, 'sp18': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7740881443023682
# Hand On Board!
# 0.6929104328155518
# Hand On Board!
# 0.6333789825439453
# Hand On Board!
# 0.8076860904693604
# Hand On Board!
# 0.79390549659729
# Hand On Board!
# 0.8070449829101562
# Hand On Board!
# 0.8008518218994141
# Hand On Board!
# 0.7841589450836182
# Hand On Board!
# 0.7787647247314453
# Hand On Board!
# 0.7897384166717529
# Hand On Board!
# 0.7973113059997559
# Hand On Board!
# 0.7921795845031738
# Hand On Board!
# 0.7929747104644775
# Hand On Board!
# 0.8069651126861572
# Hand On Board!
# 0.8103084564208984
# Hand On Board!
# 0.7936739921569824
# Hand On Board!
# 0.7235667705535889
# Hand On Board!
# 0.6970250606536865
# Hand On Board!
# 0.6240081787109375
# Hand On Board!
# 0.6448533535003662
# Hand On Board!
# 0.616628885269165
# Hand On Board!
# 0.6149771213531494
# Hand On Board!
# 0.6606121063232422
# Hand On Board!
# 0.7224204540252686
# Hand On Board!
# 0.6783409118652344
# Hand On Board!
# 0.564831018447876
# Hand On Board!
# 0.565582275390625
# Hand On Board!
# 0.5394513607025146
# Hand On Board!
# 0.6964375972747803
# Hand On Board!
# 0.7533321380615234
# Hand On Board!
# 0.5531466007232666
# Hand On Board!
# 0.5605053901672363
# Hand On Board!
# 0.6823441982269287
# Hand On Board!
# 0.6366422176361084
# Hand On Board!
# 0.7231512069702148
# Hand On Board!
# 0.6542074680328369
# Hand On Board!
# 0.6549994945526123
# Hand On Board!
# 0.5599372386932373
# Hand On Board!
# 0.8309669494628906
# Hand On Board!
# 0.7308893203735352
# Hand On Board!
# 0.6335532665252686
# Hand On Board!
# 0.7388572692871094
# Hand On Board!
# 0.6863241195678711
# Hand On Board!
# 0.639338493347168
# Hand On Board!
# 0.5808064937591553
# Hand On Board!
# 0.7431237697601318
# Hand On Board!
# 0.6843774318695068
# 221
# {'b336': 0.0} {'b336': -1.0, 'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0, 'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 1.0} {} {} {'mc21': 6.0} {'mc21': 3.0, 'w1678': 2.0} {}
# {} {} {} {} {'mc21': 5.0} {'mc21': 0.0} {}
# {} {} {} {} {'mc21': 7.0} {'mc21': 4.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7988317012786865
# Hand On Board!
# 0.7862334251403809
# Hand On Board!
# 0.7010676860809326
# Hand On Board!
# 0.7461919784545898
# Hand On Board!
# 0.5252265930175781
# Hand On Board!
# 0.6807985305786133
# Hand On Board!
# 0.7097868919372559
# Hand On Board!
# 0.7137405872344971
# Hand On Board!
# 0.6602046489715576
# Hand On Board!
# 0.6679215431213379
# Hand On Board!
# 0.6391956806182861
# Hand On Board!
# 0.7069637775421143
# Hand On Board!
# 0.6412184238433838
# Hand On Board!
# 0.7830274105072021
# Hand On Board!
# 0.8312194347381592
# Hand On Board!
# 0.6895990371704102
# 238
# {'b336': 0.0} {'b336': -1.0, 'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0, 'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 1.0, 'w1697': 2.0} {} {} {'mc21': 6.0} {'mc21': 3.0, 'w1678': 2.0} {}
# {} {'sp30': 2.0, 'w1697': 2.0} {'sp30': 0.0} {'sp30': 2.0, 'w1698': 2.0} {'mc21': 5.0, 'w1698': 2.0} {'mc21': 0.0} {}
# {} {'w1697': 2.0} {} {} {'mc21': 7.0} {'mc21': 4.0} {}
# {} {'sw241': 2.0, 'w1697': 2.0} {'sw241': 0.0} {'sw241': 2.0} {} {} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# Hand On Board!
# 0.7835850715637207
# Hand On Board!
# 0.8027098178863525
# Hand On Board!
# 0.7544536590576172
# Hand On Board!
# 0.6483249664306641
# Hand On Board!
# 0.721280574798584
# Hand On Board!
# 0.8001055717468262
# Hand On Board!
# 0.6111299991607666
# Hand On Board!
# 0.7069580554962158
# Hand On Board!
# 0.6537008285522461
# Hand On Board!
# 0.6195871829986572
# Hand On Board!
# 0.627873420715332
# Hand On Board!
# 0.7838001251220703
# Hand On Board!
# 0.6355302333831787
# Hand On Board!
# 0.6446664333343506
# Hand On Board!
# 0.7525808811187744
# Hand On Board!
# 0.8020446300506592
# Hand On Board!
# 0.7296066284179688
# Hand On Board!
# 0.7209627628326416
# Hand On Board!
# 0.8711180686950684
# Hand On Board!
# 0.8260467052459717
# Hand On Board!
# 0.7677724361419678
# Hand On Board!
# 0.7969968318939209
# Hand On Board!
# 0.7212953567504883
# Hand On Board!
# 0.7958419322967529
# Hand On Board!
# 0.7203006744384766
# Hand On Board!
# 0.7460393905639648
# Hand On Board!
# 0.8494873046875
# Hand On Board!
# 0.792339563369751
# Hand On Board!
# 0.8424952030181885
# Hand On Board!
# 0.7205595970153809
# Hand On Board!
# 0.803431510925293
# Hand On Board!
# 0.8058669567108154
# Hand On Board!
# 0.6984317302703857
# Hand On Board!
# 0.7203459739685059
# 275
# {'b336': 0.0} {'b336': -1.0, 'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0, 'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 1.0, 'w1697': 2.0} {} {} {'mc21': 6.0} {'mc21': 3.0, 'w1678': 2.0} {}
# {} {'sp30': 2.0, 'w1697': 2.0} {'sp30': 0.0} {'sp30': 2.0, 'w1698': 2.0} {'mc21': 5.0, 'w1698': 2.0} {'mc21': 0.0} {}
# {} {'w1697': 2.0} {} {} {'mc21': 7.0} {'mc21': 4.0, 'w1712': 2.0} {}
# {} {'sw241': 2.0, 'w1697': 2.0} {'sw241': 0.0} {'sw241': 2.0, 'w1713': 2.0} {'w1713': 2.0} {'w1712': 2.0, 'w1713': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}
#
# OUTPUTS:
# 0: b336 battery piece added 1.0 28,
# mc1 mc piece added 0.7 36,
# sp1 speaker piece added 0.5 38,
# w1589 wire piece added 0.5 38,
# connection added 0.5 38,
# w1592 wire piece added 0.5 40,
# connection added 0.5 40,
# bsw290 button_switch piece added 0.0 44,
# sw218 switch piece added 0.0 44,
# connection added 0.0 44,
# bsw290 button_switch piece removed 1.0 46,
# connection removed 1.0 46,
# w1599 wire piece added 1.0 49,
# sw218 switch piece removed 1.0 49,
# sw220 switch piece added 1.0 51,
# w1601 wire piece added 1.0 51,
# connection added 1.0 51,
# w1599 wire piece removed 1.0 51,
# connection removed 1.0 51,
# sp9 speaker piece added 0.782608695652174 71,
# connection added 0.782608695652174 71,
# w1603 wire piece added 0.782608695652174 71,
# connection added 0.782608695652174 71,
# w1604 wire piece added 0.782608695652174 71,
# connection added 0.782608695652174 71,
# mc1 mc piece removed 0.782608695652174 71,
# connection removed 0.782608695652174 71,
# w1589 wire piece removed 0.782608695652174 71,
# connection removed 0.782608695652174 71,
# w1592 wire piece removed 0.782608695652174 71,
# connection removed 0.782608695652174 71,
# w1601 wire piece removed 0.782608695652174 71,
# connection removed 0.782608695652174 71,
# w1607 wire piece added 0.782608695652174 72,
# connection added 0.782608695652174 72,
# sp9 speaker piece removed 0.75 80,
# connection removed 0.75 80,
# mc9 mc piece added 0.05555555555555555 98,
# connection added 0.05555555555555555 98,
# sp13 speaker piece added 0.05555555555555555 98,
# sw225 switch piece added 0.05555555555555555 98,
# sp1 speaker piece removed 0.05555555555555555 98,
# connection removed 0.05555555555555555 98,
# sw220 switch piece removed 0.05555555555555555 98,
# connection removed 0.05555555555555555 98,
# w1603 wire piece removed 0.05555555555555555 98,
# connection removed 0.05555555555555555 98,
# w1604 wire piece removed 0.05555555555555555 98,
# connection removed 0.05555555555555555 98,
# w1607 wire piece removed 0.05555555555555555 98,
# connection removed 0.05555555555555555 98,
# w1614 wire piece added 1.0 100,
# w1615 wire piece added 0.0 105,
# connection added 0.0 105,
# w1618 wire piece added 0.2857142857142857 111,
# connection added 0.2857142857142857 111,
# w1619 wire piece added 0.2857142857142857 111,
# connection added 0.2857142857142857 111,
# w1620 wire piece added 0.2857142857142857 111,
# connection added 0.2857142857142857 111,
# sp18 speaker piece added 0.7142857142857143 124,
# connection added 0.7142857142857143 124,
# w1627 wire piece added 0.7142857142857143 124,
# connection added 0.7142857142857143 124,
# sp13 speaker piece removed 0.7142857142857143 124,
# w1620 wire piece removed 0.7142857142857143 124,
# connection removed 0.7142857142857143 124,
# w1635 wire piece added 0.7142857142857143 125,
# sp21 speaker piece added 0.5 135,
# connection added 0.5 135,
# w1641 wire piece added 0.5 135,
# connection added 0.5 135,
# w1643 wire piece added 0.5 135,
# connection added 0.5 135,
# w1635 wire piece removed 0.5 135,
# connection removed 0.5 135,
# w1648 wire piece added 1.0 140,
# connection added 1.0 140,
# sp21 speaker piece removed 1.0 140,
# connection removed 1.0 140,
# w1641 wire piece removed 1.0 140,
# connection removed 1.0 140,
# w1643 wire piece removed 1.0 140,
# connection removed 1.0 140,
# mc18 mc piece added 1.0 141,
# connection added 1.0 141,
# w1664 wire piece added 0.5 151,
# connection added 0.5 151,
# w1665 wire piece added 0.5 151,
# connection added 0.5 151,
# w1667 wire piece added 0.5 151,
# connection added 0.5 151,
# mc9 mc piece removed 0.5 151,
# connection removed 0.5 151,
# w1614 wire piece removed 0.5 151,
# connection removed 0.5 151,
# w1619 wire piece removed 0.5 151,
# connection removed 0.5 151,
# w1627 wire piece removed 0.5 151,
# connection removed 0.5 151,
# w1648 wire piece removed 0.5 151,
# connection removed 0.5 151,
# mc21 mc piece added 0.25 155,
# connection added 0.25 155,
# mc18 mc piece removed 0.25 155,
# connection removed 0.25 155,
# w1673 wire piece added 0.55 171,
# connection added 0.55 171,
# w1678 wire piece added 0.55 171,
# connection added 0.55 171,
# sw225 switch piece removed 0.265625 221,
# connection removed 0.265625 221,
# w1615 wire piece removed 0.265625 221,
# connection removed 0.265625 221,
# w1618 wire piece removed 0.265625 221,
# connection removed 0.265625 221,
# sp18 speaker piece removed 0.265625 221,
# connection removed 0.265625 221,
# w1664 wire piece removed 0.265625 221,
# connection removed 0.265625 221,
# w1665 wire piece removed 0.265625 221,
# connection removed 0.265625 221,
# w1667 wire piece removed 0.265625 221,
# sp30 speaker piece added 0.6666666666666666 238,
# sw241 switch piece added 0.6666666666666666 238,
# w1697 wire piece added 0.6666666666666666 238,
# connection added 0.6666666666666666 238,
# w1698 wire piece added 0.6666666666666666 238,
# connection added 0.6666666666666666 238,
# w1712 wire piece added 0.20512820512820512 275,
# connection added 0.20512820512820512 275,
# w1713 wire piece added 0.20512820512820512 275,
# connection added 0.20512820512820512 275,
#
# 1: b336 battery piece added 0.0 28,
# mc1 mc piece added 0.3 36,
# sp1 speaker piece added 0.5 38,
# w1589 wire piece added 0.5 38,
# connection added 0.5 38,
# w1592 wire piece added 0.5 40,
# connection added 0.5 40,
# bsw290 button_switch piece added 1.0 44,
# sw218 switch piece added 1.0 44,
# connection added 1.0 44,
# bsw290 button_switch piece removed 0.0 46,
# connection removed 0.0 46,
# w1599 wire piece added 0.0 49,
# sw218 switch piece removed 0.0 49,
# sw220 switch piece added 0.0 51,
# w1601 wire piece added 0.0 51,
# connection added 0.0 51,
# w1599 wire piece removed 0.0 51,
# connection removed 0.0 51,
# sp9 speaker piece added 0.21739130434782608 71,
# connection added 0.21739130434782608 71,
# w1603 wire piece added 0.21739130434782608 71,
# connection added 0.21739130434782608 71,
# w1604 wire piece added 0.21739130434782608 71,
# connection added 0.21739130434782608 71,
# mc1 mc piece removed 0.21739130434782608 71,
# connection removed 0.21739130434782608 71,
# w1589 wire piece removed 0.21739130434782608 71,
# connection removed 0.21739130434782608 71,
# w1592 wire piece removed 0.21739130434782608 71,
# connection removed 0.21739130434782608 71,
# w1601 wire piece removed 0.21739130434782608 71,
# connection removed 0.21739130434782608 71,
# w1607 wire piece added 0.21739130434782608 72,
# connection added 0.21739130434782608 72,
# sp9 speaker piece removed 0.25 80,
# connection removed 0.25 80,
# mc9 mc piece added 0.9444444444444444 98,
# connection added 0.9444444444444444 98,
# sp13 speaker piece added 0.9444444444444444 98,
# sw225 switch piece added 0.9444444444444444 98,
# sp1 speaker piece removed 0.9444444444444444 98,
# connection removed 0.9444444444444444 98,
# sw220 switch piece removed 0.9444444444444444 98,
# connection removed 0.9444444444444444 98,
# w1603 wire piece removed 0.9444444444444444 98,
# connection removed 0.9444444444444444 98,
# w1604 wire piece removed 0.9444444444444444 98,
# connection removed 0.9444444444444444 98,
# w1607 wire piece removed 0.9444444444444444 98,
# connection removed 0.9444444444444444 98,
# w1614 wire piece added 0.0 100,
# w1615 wire piece added 1.0 105,
# connection added 1.0 105,
# w1618 wire piece added 0.7142857142857143 111,
# connection added 0.7142857142857143 111,
# w1619 wire piece added 0.7142857142857143 111,
# connection added 0.7142857142857143 111,
# w1620 wire piece added 0.7142857142857143 111,
# connection added 0.7142857142857143 111,
# sp18 speaker piece added 0.2857142857142857 124,
# connection added 0.2857142857142857 124,
# w1627 wire piece added 0.2857142857142857 124,
# connection added 0.2857142857142857 124,
# sp13 speaker piece removed 0.2857142857142857 124,
# w1620 wire piece removed 0.2857142857142857 124,
# connection removed 0.2857142857142857 124,
# w1635 wire piece added 0.2857142857142857 125,
# sp21 speaker piece added 0.5 135,
# connection added 0.5 135,
# w1641 wire piece added 0.5 135,
# connection added 0.5 135,
# w1643 wire piece added 0.5 135,
# connection added 0.5 135,
# w1635 wire piece removed 0.5 135,
# connection removed 0.5 135,
# w1648 wire piece added 0.0 140,
# connection added 0.0 140,
# sp21 speaker piece removed 0.0 140,
# connection removed 0.0 140,
# w1641 wire piece removed 0.0 140,
# connection removed 0.0 140,
# w1643 wire piece removed 0.0 140,
# connection removed 0.0 140,
# mc18 mc piece added 0.0 141,
# connection added 0.0 141,
# w1664 wire piece added 0.5 151,
# connection added 0.5 151,
# w1665 wire piece added 0.5 151,
# connection added 0.5 151,
# w1667 wire piece added 0.5 151,
# connection added 0.5 151,
# mc9 mc piece removed 0.5 151,
# connection removed 0.5 151,
# w1614 wire piece removed 0.5 151,
# connection removed 0.5 151,
# w1619 wire piece removed 0.5 151,
# connection removed 0.5 151,
# w1627 wire piece removed 0.5 151,
# connection removed 0.5 151,
# w1648 wire piece removed 0.5 151,
# connection removed 0.5 151,
# mc21 mc piece added 0.75 155,
# connection added 0.75 155,
# mc18 mc piece removed 0.75 155,
# connection removed 0.75 155,
# w1673 wire piece added 0.45 171,
# connection added 0.45 171,
# w1678 wire piece added 0.45 171,
# connection added 0.45 171,
# sw225 switch piece removed 0.734375 221,
# connection removed 0.734375 221,
# w1615 wire piece removed 0.734375 221,
# connection removed 0.734375 221,
# w1618 wire piece removed 0.734375 221,
# connection removed 0.734375 221,
# sp18 speaker piece removed 0.734375 221,
# connection removed 0.734375 221,
# w1664 wire piece removed 0.734375 221,
# connection removed 0.734375 221,
# w1665 wire piece removed 0.734375 221,
# connection removed 0.734375 221,
# w1667 wire piece removed 0.734375 221,
# sp30 speaker piece added 0.3333333333333333 238,
# sw241 switch piece added 0.3333333333333333 238,
# w1697 wire piece added 0.3333333333333333 238,
# connection added 0.3333333333333333 238,
# w1698 wire piece added 0.3333333333333333 238,
# connection added 0.3333333333333333 238,
# w1712 wire piece added 0.7948717948717948 275,
# connection added 0.7948717948717948 275,
# w1713 wire piece added 0.7948717948717948 275,
# connection added 0.7948717948717948 275,
#
#
# {'b336': 0.0} {'b336': -1.0, 'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0} {'w1673': 2.0, 'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 0.0} {} {} {} {'w1678': 2.0} {}
# {'b336': 0.0} {'b336': 1.0, 'w1697': 2.0} {} {} {'mc21': 6.0} {'mc21': 3.0, 'w1678': 2.0} {}
# {} {'sp30': 2.0, 'w1697': 2.0} {'sp30': 0.0} {'sp30': 2.0, 'w1698': 2.0} {'mc21': 5.0, 'w1698': 2.0} {'mc21': 0.0} {}
# {} {'w1697': 2.0} {} {} {'mc21': 7.0} {'mc21': 4.0, 'w1712': 2.0} {}
# {} {'sw241': 2.0, 'w1697': 2.0} {'sw241': 0.0} {'sw241': 2.0, 'w1713': 2.0} {'w1713': 2.0} {'w1712': 2.0, 'w1713': 2.0} {}
# {} {} {} {} {} {} {}
# {} {} {} {} {} {} {}

# %%
mastery_updater.finish_cv(cap)
