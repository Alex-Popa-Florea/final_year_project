# %%
import mastery_updater

# %%
unique_uids = [5, 4]
tids = ["task1", "task2", "task3", "task4"]

# %%
uids = []
for i, uid in enumerate(unique_uids):
    uids.append(i)
user_masteries = mastery_updater.FullMasteries(uids, tids)
correct_init, (source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size) = mastery_updater.initialise_cv()
# Out:
# {(0, 0): array([84, 81], dtype=int64), (0, 1): array([106,  81], dtype=int64), (0, 2): array([128,  81], dtype=int64), (0, 3): array([151,  81], dtype=int64), (0, 4): array([173,  81], dtype=int64), (0, 5): array([196,  81], dtype=int64), (0, 6): array([218,  81], dtype=int64), (0, 7): array([240,  81], dtype=int64), (1, 0): array([ 84, 103], dtype=int64), (1, 1): array([106, 103], dtype=int64), (1, 2): array([128, 103], dtype=int64), (1, 3): array([151, 103], dtype=int64), (1, 4): array([173, 103], dtype=int64), (1, 5): array([196, 103], dtype=int64), (1, 6): array([218, 103], dtype=int64), (1, 7): array([240, 103], dtype=int64), (2, 0): array([ 84, 126], dtype=int64), (2, 1): array([106, 126], dtype=int64), (2, 2): array([128, 126], dtype=int64), (2, 3): array([151, 126], dtype=int64), (2, 4): array([173, 126], dtype=int64), (2, 5): array([196, 126], dtype=int64), (2, 6): array([218, 126], dtype=int64), (2, 7): array([240, 126], dtype=int64), (3, 0): array([ 84, 148], dtype=int64),
# ...

# %%
if correct_init:
    print(unique_uids)
    valid_task, beliefs = mastery_updater.run_task(user_masteries, uids, unique_uids, source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size)
    if valid_task:
        user_masteries.move_to_next_task(beliefs)
# Out:
# [5, 4]
# 0.03894162178039551
# 0.029016494750976562
# 0.009330987930297852
# Hand On Board!
# 7
# [{'lmList': [[348, 334, 0], [342, 310, -16], [322, 292, -22], [303, 277, -23], [290, 265, -24], [293, 317, -21], [267, 298, -27], [252, 286, -30], [242, 277, -32], [290, 328, -12], [267, 306, -16], [262, 292, -16], [259, 281, -17], [291, 333, -4], [273, 313, -8], [272, 300, -8], [274, 290, -8], [293, 334, 2], [279, 318, -1], [279, 306, -2], [281, 298, -1]], 'bbox': (242, 265, 106, 69), 'center': (295, 299), 'type': 'ID: 1'}, {'lmList': [[371, 176, 0], [358, 198, -16], [335, 210, -20], [315, 223, -18], [303, 235, -14], [311, 188, -20], [278, 203, -20], [266, 217, -18], [261, 228, -15], [307, 177, -7], [271, 185, -8], [262, 198, -5], [262, 210, -2], [309, 172, 4], [282, 181, 6], [274, 193, 7], [273, 204, 9], [313, 173, 16], [294, 181, 18], [287, 191, 18], [284, 200, 19]], 'bbox': (261, 172, 110, 63), 'center': (316, 203), 'type': 'ID: 1'}]
# 0.8906590938568115
# Hand On Board!
# 8
# ...

# %%
if correct_init:
    print(unique_uids)
    valid_task, beliefs = mastery_updater.run_task(user_masteries, uids, unique_uids, source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size)
    if valid_task:
        user_masteries.move_to_next_task(beliefs)
# Out:
# [5, 4]
# 0.023880720138549805
# Hand On Board!
# 1
# [{'lmList': [[444, 28, 0], [417, 43, -5], [390, 35, -2], [374, 24, 2], [362, 14, 8], [391, 12, 11], [371, 0, 19], [358, -5, 22], [348, -9, 23], [401, 2, 16], [381, -9, 26], [367, -14, 27], [357, -18, 26], [408, -3, 20], [391, -15, 29], [379, -20, 31], [370, -25, 30], [414, -7, 24], [400, -18, 32], [390, -23, 35], [382, -27, 37]], 'bbox': (348, -27, 96, 70), 'center': (396, 8), 'type': 'ID: 1'}]
# 0.943169355392456
# 0.022519826889038086
# 0.10174179077148438
# 0.10899543762207031
# 0.010373353958129883
# 0.006487607955932617
# 0.04211163520812988
# 0.01811695098876953
# 0.05401492118835449
# 0.038355112075805664
# 0.02857041358947754
# Hand On Board!
# 17
# ...

# %%
if correct_init:
    print(unique_uids)
    valid_task, beliefs = mastery_updater.run_task(user_masteries, uids, unique_uids, source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size)
    if valid_task:
        user_masteries.move_to_next_task(beliefs)
# Out:
# [5, 4]
# 0.06434750556945801
# 0.09874224662780762
# 0.12645673751831055
# 0.13203787803649902
# Hand On Board!
# 4
# [{'lmList': [[488, 53, 0], [461, 69, -14], [433, 66, -17], [408, 55, -14], [390, 46, -9], [432, 32, -19], [397, 17, -16], [384, 25, -10], [380, 35, -5], [441, 19, -7], [403, 6, -3], [392, 19, 3], [390, 31, 8], [448, 15, 4], [416, 7, 9], [405, 17, 14], [402, 26, 17], [452, 14, 15], [427, 10, 19], [417, 18, 23], [414, 25, 25]], 'bbox': (380, 6, 108, 63), 'center': (434, 37), 'type': 'ID: 1'}]
# 0.944528341293335
# Hand On Board!
# 5
# [{'lmList': [[430, 25, 0], [406, 43, -11], [378, 44, -15], [355, 33, -17], [341, 19, -17], [377, 12, -10], [354, -5, -10], [342, -11, -11], [335, -15, -11], [386, 0, -5], [363, -16, -3], [349, -22, -2], [341, -26, -3], [395, -8, 0], [375, -22, 1], [363, -28, 2], [356, -32, 2], [402, -12, 3], [386, -25, 4], [376, -30, 6], [370, -33, 7]], 'bbox': (335, -33, 95, 77), 'center': (382, 5), 'type': 'ID: 1'}]
# 0.9329571723937988
# ...

# %%
if correct_init:
    print(unique_uids)
    valid_task, beliefs = mastery_updater.run_task(user_masteries, uids, unique_uids, source, cap, model, detector, matrix_to_recolor, peg_size, frame_tilt, frame_circle, angle, board_size)
    if valid_task:
        user_masteries.move_to_next_task(beliefs)
# Out:
# [5, 4]
# 0.08797097206115723
# 0.10300803184509277
# 0.12677907943725586
# 0.1183013916015625
# 0.02902841567993164
# 0.10860133171081543
# 0.1348741054534912
# 0.0965414047241211
# Hand On Board!
# 8
# [{'lmList': [[116, 306, 0], [118, 281, 6], [134, 264, 4], [153, 260, 2], [168, 260, 1], [141, 259, -10], [171, 250, -12], [183, 251, -9], [185, 255, -4], [150, 273, -14], [183, 264, -16], [186, 267, -9], [181, 271, -1], [157, 289, -17], [187, 280, -17], [187, 280, -7], [180, 283, 1], [162, 305, -20], [187, 294, -17], [191, 291, -8], [188, 292, 0]], 'bbox': (116, 250, 75, 56), 'center': (153, 278), 'type': 'ID: 0'}]
# 0.9420459270477295
# Hand On Board!
# 9
# ...

# %%
mastery_updater.finish_cv(cap)
